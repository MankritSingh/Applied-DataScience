# %% [markdown]
# Tasks
# 1)Bar graph

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 23.1.1 is available.
# You should consider upgrading via the 'C:\Users\hargu\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
#import
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import style# provides a convenient way to apply predefined styles to your plots.
# %matplotlib inline

df=pd.read_csv('titanic.csv')
df_cleaned=df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)
print(df_cleaned.isnull().sum())
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
survived_count=df.groupby('Survived')['Survived'].count()
survived_count
# Out:
# Survived
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#1 Bar chart
plt.title("Bar:Group by survival")
plt.bar(survived_count.index,survived_count.values)
plt.xticks([0,1],["Not survived","Survived"])
#for loop optional
for i,value in enumerate(survived_count.values):
    plt.text(i,value-70,str(value),fontsize=12,color='white')
plt.show()
#similarly do for other

# %%
survived_sex = df.groupby('Sex')['Survived'].sum()
plt.figure(figsize=(4,5))
plt.bar(survived_sex.index, survived_sex.values)
plt.title('Survived female and male')
for i, value in enumerate(survived_sex.values):
    plt.text(i, value-20, str(value), fontsize=12, color='white',
             horizontalalignment='center', verticalalignment='center')
plt.show()

# %%
#2 Pie charts
pclass_count=df.groupby('Pclass')['Pclass'].count()
plt.title("Group by pclass")
plt.pie(pclass_count.values)
#optional args
#plt.pie(pclass_count.values,labels=["Class1","Class2","Class3"],autopct='%1.1f%%',textprops={'fontsize':13})
plt.show()
#similarly make pie charts for gender,embarkation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 7
#       3 plt.title("Group by pclass")
#       4 #plt.pie(pclass_count.values,labels=["Class1","Class2","Class3"])
#       5 #optional args
#       6 #plt.pie(pclass_count.values,labels=["Class1","Class2","Class3"],autopct='%1.1f%%',textprops={'fontsize':13})
# ----> 7 plt.pie()
#       9 plt.show()
#
# TypeError: pie() missing 1 required positional argument: 'x'

# %%
#3 scatter plot
sns.lmplot(x='Age', y='Fare', data=df_cleaned, fit_reg=False, hue="Pclass", col="Embarked", scatter_kws={"marker": ".", "s": 20})
plt.subplots_adjust(top=0.9)
plt.suptitle('Scatterplot of passengers w.r.t Fare and Age for diff. ports', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Scatterplot of passengers w.r.t Fare and Age for diff. ports')
